# %%
# %pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\sumair\miniconda3\envs\webscraping_env\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sumair\miniconda3\envs\webscraping_env\lib\site-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sumair\miniconda3\envs\webscraping_env\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sumair\miniconda3\envs\webscraping_env\lib\site-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sumair\miniconda3\envs\webscraping_env\lib\site-packages (from requests) (2025.4.26)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

def get_weather_api(location):
    # Get coordinates of location
    geo_url = f"https://geocoding-api.open-meteo.com/v1/search?name={location}&count=1"
    geo_res = requests.get(geo_url).json()
    
    if "results" not in geo_res:
        return {"Error": "Location not found"}
    
    lat = geo_res["results"][0]["latitude"]
    lon = geo_res["results"][0]["longitude"]
    place = geo_res["results"][0]["name"]

    # Get current weather
    weather_url = f"https://api.open-meteo.com/v1/forecast?latitude={lat}&longitude={lon}&current_weather=true"
    weather_res = requests.get(weather_url).json()
    
    current = weather_res.get("current_weather", {})
    
    return {
        "Location": place,
        "Temperature (°C)": current.get("temperature"),
        "Windspeed (km/h)": current.get("windspeed"),
        "Time": current.get("time")
    }

# Example
if __name__ == "__main__":
    loc = input("Enter location: ")
    print(get_weather_api(loc))
# Out:
# {'Location': 'Sargodha', 'Temperature (°C)': 34.8, 'Windspeed (km/h)': 5.9, 'Time': '2025-09-22T06:15'}
